# %%
! pip3 freeze | grep scip
# ! pip3 install scipy==1.5.4
# Out:
# scipy==1.5.4

# %%
from scipy.io import wavfile
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

# %%
sample_rate, samples = wavfile.read('audio/ARU04_20111108_140000.wav')

# %%
sample_rate
# Out:
# 16000

# %%
samples.shape[0] / sample_rate
# Out:
# 1800.0073125

# %%
1800 / (257098 / sample_rate)
# Out:
# 112.01954118662921

# %%
129 / sample_rate
# Out:
# 0.0080625

# %%
(samples.shape[0] / 16000) / 60
# Out:
# 30.000121874999998

# %%
samples.shape
# Out:
# (28800117, 2)

# %%
samples = samples[:20000]

# %%
samples.shape
# Out:
# (9000, 2)

# %%
? np.ndarray

# %%
channels = np.array([ch1 for bothchannels in samples for ch1 in bothchannels])
channel1 = channels[::1]
channel2 = channels[::2]
del channels

# %%
n = 0
channel1[n], channel2[n]
# Out:
# (0, 0)

# %%
? signal.spectrogram

# %%
frequencies, times, spectrogram = signal.spectrogram(channel1, sample_rate)

# %%
frequencies.shape
# Out:
# (129,)

# %%
times.shape
# Out:
# (257143,)

# %%
signal.spectrogram( np.random.standard_normal(100), 50 )
# Out:
# (array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#          5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#         11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ,
#         16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. , 20.5, 21. , 21.5,
#         22. , 22.5, 23. , 23.5, 24. , 24.5, 25. ]),
#  array([1.]),
#  array([[1.23850914e-04],
#         [3.70629118e-02],
#         [2.17770080e-02],
#         [7.71692320e-03],
#         [6.96606407e-04],
#         [1.52706182e-02],
#         [2.60213537e-02],
#         [3.14492936e-02],
#         [1.77853265e-02],
#         [1.13370466e-02],
#         [4.42350117e-03],
#         [4.96040561e-02],
#         [1.17733109e-02],
#         [1.20905807e-01],
#         [1.22630916e-02],
#         [4.33667467e-02],
#         [2.48086297e-02],
#         [2.63185532e-02],
#         [7.48573378e-02],
#         [1.04027115e-02],
#         [1.85665197e-01],
#         [4.26505740e-02],
# ...

# %%
spectrogram.shape
# Out:
# (129, 257143)

# %%
def plotSpectrogramFromWavArray (channel, samplerate):
    frequencies, times, spectrogram = signal.spectrogram(channel, sample_rate)
    print(frequencies)
    plt.pcolormesh(times, frequencies, spectrogram)
#     plt.imshow(spectrogram1)
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.show()

# %%
plotSpectrogramFromWavArray(channel1, sample_rate)

# %%
plotSpectrogramFromWavArray(channel2, sample_rate)
